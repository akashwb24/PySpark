# %%
df = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/Products.csv")
    .option("header","true")
    .option("inferSchema","true")
    .load()
)
df.display()

# %%
display(dbutils.fs.ls("/Volumes/workspace/default/practice/SMALLCSV"))

# %%
df2 = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/SMALLCSV")
    .option("header",True)
    .option("inferSchema",True)
    .load()
)
display(df2)

# %%
joindf = df.join(df2,df.payment_type == df2.payment_typeID)
display(joindf)

# %%
spark.conf.get("spark.sql.autoBroadcastJoinThreshold")

# %%
joindf.explain(True)

# %%
spark.conf.get("spark.sql.broadcastTimeout")

# %%
from pyspark.sql.functions import broadcast

# %%
joindf = df.join(broadcast(df2),df.payment_type == df2.payment_typeID)
display(joindf)

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold",20*1024*1024)

# %%
spark.conf.set("spark.sql.autoBroadcastJoinThreshold",-1)
#disable
