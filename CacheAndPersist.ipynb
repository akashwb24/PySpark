# %%
df1 = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
display(df1)

# %%
df2 = df1.select("OrderDate","InvoiceNum","ProductKey","EnglishProductName","Country","SalesAmount")

# %%
from pyspark.sql.functions import *

# %%
df3 = df2.withColumn("Vat",expr("SalesAmount * 0.5 as Vat"))

# %%
df4 = df3.filter("Country = 'India'")

# %%
df1.count()

# %%
df2.count()

# %%
df3.count()

# %%
df4.count()

# %%
df2.cache()

# %%
df2.count()

# %%
df1.is_cached

# %%
df2.is_cached

# %%
df2.unpersist()

# %%
from pyspark.storagelevel import StorageLevel

# %%
help(StorageLevel)

# %%
df2.persist(StorageLevel.MEMORY_ONLY)

# %%
df2.count()

# %%
df2.unpersist()

# %%
df2.persisit(StorageLevel.MEMORY_ONLY_SERIALIZED)

# %%
df2.persist(StorageLevel.MEMORY_AND_DISK)

# %%
df2.unpersist()

# %%
df2.persist(StorageLevel.DISK_ONLY)

# %%
df2.persist(StorageLevel.DISK_ONLY_3)
