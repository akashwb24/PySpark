# %%
# %run /Workspace/Users/pakask23@gmail.com/PySparkMV/CalledNotebook

# %%
double(2)

# %%
x

# %%
# %run /Workspace/Users/pakask23@gmail.com/PySpark/widgets $country = "uk"

# %%
# %run ../

# %%
dbutils.notebook.run ("/Workspace/Users/pakask23@gmail.com/PySpark/widgets",10,{"country":"US"})
