# %%
df = spark.read.format("csv").option("path","path").option("header",True).load()
display(df)

# %%
df.write.format("delta").option("path","path").saveAsTable("tblstats")

# %%
df_log = spark.read.format("json").option("path","path").load()
display(df_log)

# %%
# %sql
alter table tblcolstats
set tblproperties ('delta.dataskippingNumIndexedCols' = 40);

# %%
df_log = spark.read.format("json").option("path","path").load()
display(df_log)

# %%
df.write.format("delta").option("path","path").mode("overwrite").saveAsTable("tblcolstats")

# %%
df_log = spark.read.format("json").option("path","path").load()

# %%
display(df_log)
