# %%
df1 = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/EmployeesNew.csv").option("header",True).option("inferschema",True).load()
df1.display()

# %%
df2 = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/EmployeesNew.csv").option("header",True).option("inferschema",True).load()
df2.display()

# %%
df3 = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/EmployeesNew2.csv").option("header",True).option("inferschema",True).load()
df3.display()

# %%
df4=df1.union(df2).distinct() #here union is used to combine two dataframes but it doesnt remove the duplicate values as in tsql, we have do it manually
display(df4)

# %%
df5 = df1.unionByName(df3).distinct()
display(df5)

# %%
df6 = df1.union(df2).union(df3)
df6.display()
