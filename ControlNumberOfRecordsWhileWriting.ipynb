# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
df.write.format("csv").option("header",True).option("inferSchema",True).option("path","/Volumes/workspace/default/practice/MaxRecords/").option("maxRecordsPerFile",500).mode("overwrite").save()

# %%
display(spark.read.text("/Volumes/workspace/default/practice/MaxRecords/part-00000-tid-7643221221955452640-145765e8-dc30-4884-a5ad-5ee400c3e246-241-1-c000.csv"))

# %%
df2 = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/MaxRecords/part-00000-tid-7643221221955452640-145765e8-dc30-4884-a5ad-5ee400c3e246-241-1-c000.csv").option("header",True).option("inferSchema",True).load()
df2.display()

# %%
display(dbutils.fs.ls("/Volumes/workspace/default/practice/MaxRecords/"))
