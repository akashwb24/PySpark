# %%
# %sql
create table tbl_employee
(
  id int,
  name string,
  city string,
  salary double
)
using delta

# %%
# %sql
copy into tbl_employee
from (
  select
  id::integer,
  name::string,
  city::string,
  salary::double
  from '/Volumes/workspace/default/practice/Employees.csv'
)
fileformat = CSV
format_options('header'='true')

# %%
# %sql
select * from tbl_employee

# %%
# %sql
copy into tbl_employee
from (
  select
  id::integer,
  name::string,
  city::string,
  salary::double
  from '/Volumes/workspace/default/practice/Employees.csv'
)
fileformat = CSV
format_options('header'='true')
--wont run again, that means it is said idempotent

# %%
# %sql
create table tbl_employee_new
using delta

# %%
# %sql
copy into tbl_employee_new
from '/Volumes/workspace/default/practice/Employees.csv'
fileformat = CSV
format_options ('inferSchema' = 'true', 'mergeSchema' = 'true', 'header' = 'true')
copy_options ('mergeSchema' = 'true')

# %%
# %sql
select * from tbl_employee_new

# %%
format_options(
  'mergeSchema' = 'true',
  'delimiter' = '|',
  'header' = 'true'
)
