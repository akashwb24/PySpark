# %%
dfproducts = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
display(dfproducts)

# %%
dfproducts.write.format("delta").saveAsTable("tblProductsNew")

# %%
# %sql
create database if not exists mydb

# %%
# %sql
create table if not exists mydb.Products
(
  ProductID int,
  ProductName string
)
using DELTA

# %%
# %sql
create table if not exists mydb.Products
(
  ProductID int,
  ProductName string
)
using DELTA
location 'workspace.mydb'

# %%
# %sql
describe detail mydb.products

# %%
df=spark.read.format("json").option("path","/Volumes/workspace/default/practice/Products.json").load()
display(df)

# %%
# %sql
describe table extended mydb.products

# %%
from delta.tables import *

# %%
help(DeltaTable.createIfNotExists(spark))

# %%
(DeltaTable.createIfNotExists(spark)
 .tableName("mydb.my_table")
 .addColumn("productid","int")
 .addColumn("productname","string")
 .addColumn("price","double")
 .addColumn("startdate","timestamp")
 .execute()
)

# %%
# %sql
describe table extended mydb.my_table
