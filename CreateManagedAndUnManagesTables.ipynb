# %%
df = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/Products.csv")
    .option("header",True)
    .option("inferSchema",True)
    .load()
)
df.display()

# %%
df.write.saveAsTable("tblProducts")

# %%
# %sql
show databases

# %%
# %sql
show tables

# %%
# %sql
describe table tblproducts

# %%
# %sql
describe detail tblproducts

# %%
# %sql
drop table tblproducts

# %%
df.write.saveAsTable("mydb.tblProducts")

# %%
df.write.option("path","/Volumes/workspace/default/Tables/ExtTbl").saveAsTable("tblProduct")
