# %%
df = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/Products.csv")
    .option("header",True)
    .option("inferSchema",True)
    .load()
)
display(df)

# %%
df.createOrReplaceTempView("VwProducts")

# %%
# %sql
select * from VwProducts

# %%
display(spark.catalog.listDatabases())

# %%
# %sql
show databases

# %%
# %sql
create database mydb

# %%
display(spark.catalog.listTables())

# %%
# %sql
show tables

# %%
df.createOrReplaceGlobalTempView("prods")

# %%
# %sql
select * from global_temp.prods

# %%
spark.catalog.dropTempView("prods")

# %%
spark.catalog.dropGlobalTempView("")
