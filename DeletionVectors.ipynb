# %%
df = spark.range(100000000)

# %%
df.write.saveAsTable("tblids")

# %%
# %sql
show tblproperties tblids

# %%
# %sql
delete from tblids where id = 182638

# %%
# %sql
alter table tblids set tblproperties('delta.enableDeletionVectors'='true')

# %%
# %sql
describe detail tblids

# %%
# %sql
delete from tblids where id = 37535

# %%
# %sql
reorg table tblids apply(purge)

# %%
# %sql
delete from tblids where id = 645433

# %%
# %sql
set spark.databricks.delta.retentionDurationCheck=false

# %%
# %sql
vacuum tblids retain 1 hours

# %%
# %sql
delete from tblids where id = 645436

# %%
# %sql
delete from tblids where id = 456321

# %%
# %sql
describe detail tblids

# %%
# %sql
reorg table tblids apply(purge)

# %%
# %sql
vacuum tblids retain 1 hours

# %%
# %sql
delete from tblids where id in (123654,456321,789654,456987)

# %%
# %sql
reorg table tblids apply(purge)

# %%
# %sql
vacuum tblids retain 1 hours
