# %%
df=(spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load())
df.display()

# %%
# ✅ Use a fresh folder that has no existing files
df.write.format("delta").option("path", "/Volumes/workspace/default/practice/DeltaFormat/").save()

# %%
df2=(spark.read.format("json").option("path","/Volumes/workspace/default/practice/DeltaFormat/_delta_log/00000000000000000000.json").load())
df2.display()

# %%
/Volumes/workspace/default/practice/DeltaFormat/_delta_log/00000000000000000000.json

# %%
df3=(spark.read.format("delta").option("path","/Volumes/workspace/default/practice/DeltaFormat").load())
df3.display()
