# %%
df=spark.read.format("csv").option("path","/Volumes/workspace/default/practice/EmployeeNulls.csv").option("header",True).option("inferSchema",True).load()
display(df)

# %%
df2 = df.fillna(0)
df2.display()

# %%
df3 = df.na.fill(0)
df3.display()

# %%
df4 = df.na.fill(0).na.fill("na")
df4.display()

# %%
from pyspark.sql.functions import *

# %%
df5 = df.withColumn("id",coalesce("id",lit(0)))
display(df5)
