# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
df2 = df.filter("ProductKey == 214")
df2.display()

# %%
df2 = df.filter("ProductKey != 214")
df2.display()

# %%
df3 = df.filter("SalesAmount > 1000")
df3.display()

# %%
df4 = df.filter("Country == 'Australia'")
df4.display()

# %%
df4 = df.filter("Country != 'Australia'")
df4.display()

# %%
df5 = df.filter("ProductKey == 214 AND Country == 'Australia'")
df5.display()

# %%
df5 = df.filter("Country == 'Italy' OR Country == 'Australia'")
df5.display()

# %%
df6 = df.filter("SalesAmount >= 1000 AND SalesAmount <=2000")
df6.display()

# %%
from pyspark.sql.functions import col

# %%
df7 = df.filter(col("SalesAmount").between(1000,2000))
df7.display()
