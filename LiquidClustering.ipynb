# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
display(df)

# %%
# %sql
create table tblempnew(
  orderdate timestamp,
  invoicenum string,
  country string,
  salesamount double
)
cluster by (Country)

# %%
# %sql
describe table tblempnew

# %%
# %sql
describe detail tblempnew

# %%
# %sql
create table tblempnew2(
  orderdate timestamp,
  invoicenum string,
  country string,
  salesamount double
)

# %%
# %sql
describe table tblempnew2

# %%
# %sql
describe detail tblempnew2

# %%
# %sql
alter table tblempnew2
cluster by (Country)

# %%
# %sql
describe table tblempnew2

# %%
from pyspark.sql.functions import *

# %%
df.select(col("orderdate").cast("timestamp"),"invoicenum","country","salesamount").write.mode("append").saveAsTable("tblempn")

# %%
# %sql
optimize tblempn

# %%
# %sql
alter table tblempnew
cluster by none

# %%
# %sql
describe table tblempnew
