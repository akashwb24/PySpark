# %%
1
spark.conf.set("fs.azure.account.key.cdudevmyadls.dfs.core.windows.net",
"FEMAM5XrIDGE10hdGLvyvwk1bzT98jYvdYuy+1JMp0r60QNj34TpAjr+Z32RGoWF418yGjbhNz9G+AStlavy9g==")

# %%
df = (spark.read.format("csv")
.option("path", "abfss://mycontainer@cdudevmyadls.dfs.core.windows.net/CSVfiles/tripdata/tripdataNew.csv")
.load())

# %%
df.rdd.getNumPartitions()

# %%
spark.conf.get("spark.sql.files.maxPartitionBytes")

# %%
spark.conf.set("spark.sql.files.maxPartitionBytes",512*1024*1024)

# %%
df2 = (spark.read.format("csv")
.option("path", "abfss://mycontainer@cdudevmyadls.dfs.core.windows.net/CSVfiles/tripdata/tripdatalew.csv")
.option("header", True)
.option("inferschema", True)
.load())
display(df2)

# %%
spark.conf.set("spark.sql.files.maxPartitionBytes",256*1024*1024)

# %%
df3 = (spark.read.format("csv")
.option("path", "abfss://mycontainer@cdudevmyadls.dfs.core.windows.net/CSVfiles/tripdata/tripdataNew.csv")
.option("header", True)
.option("inferschema", True)
.load())
display(df3)

# %%
df3.rdd.getNumPartitions()

# %%
from pyspark.sql.functions import spark_partition_id

# %%
display(df3.groupBy(spark_partition_id()).count())
