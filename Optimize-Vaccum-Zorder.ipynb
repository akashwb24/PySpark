# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
display(df)

# %%
df.repartition(4).write.format("delta").saveAsTable("tblPerformance")

# %%
# %sql
describe history tblPerformance

# %%
# %sql
update tblperformance set Country = 'USA' where Country = 'United States'

# %%
# %sql
vacuum tblPerformance retain 0 hours dry run

# %%
spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", "true")

# %%
# %sql
optimize tblPerformance

# %%
# %sql
vacuum tblPerformance

# %%
# %sql
describe history tblPerformance

# %%
spark.conf.get("spark.databricks.delta.optimize.maxFileSize")

# %%
from delta.tables import *
deltaTable = DeltaTable.forPath(spark, "/Volumes/workspace/default/practice/tblPerformance")
deltaTable.logRetentionDuration = "interval 40 days"
deltaTable.deletedFileRetentionDuration = "interval 10 days"

# %%
deltaTable.logRetentionDuration

# %%
deltaTable.deletedFileRetentionDuration

# %%
df.repartition(4).write.format("delta").partitionBy("Country").saveAsTable("tblPerformanceNew")

# %%
# %sql
optimize tblPerformanceNew where Country = 'India'

# %%
# %sql
vacuum tblPerformanceNew

# %%
# %sql
describe history tblPerformanceNew

# %%
df.repartition(7).write.format("delta").saveAsTable("tblPerformanceZ")

# %%
# %sql
set spark.databricks.delta.formatCheck.enabled=false

# %%
# %sql
set spark.databricks.delta.formatCheck.enabled=true

# %%
# %sql
optimize tblPerformanceZ zorder by (Country)
