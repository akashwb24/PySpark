# %%
df = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/Products.csv")
    .option("header",True)
    .option("inferSchema",True)
    .load()
)
df.display()

# %%
df.write.option("path","/Volumes/workspace/default/practice/Partition/").partitionBy("Country").save()

# %%
df2 = (
    spark.read.format("parquet")
    .option("path","/Volumes/workspace/default/practice/Partition/Country=France/part-00003-39c2b748-5cab-46fb-8d6e-b1742fdd731a.c000.snappy.parquet")
    .load()
)
df2.display()

# %%
df2 = (
    spark.read.format("delta")
    .option("path","/Volumes/workspace/default/practice/Partition/Country=France/part-00003-39c2b748-5cab-46fb-8d6e-b1742fdd731a.c000.snappy.parquet")
    .load()
)
df2.display()

# %%
# %sql
SET spark.databricks.DELTA.formatCheck.enabled=false

# %%
df2 = (
    spark.read.format("parquet")
    .option("path","/Volumes/workspace/default/practice/Partition/Country=France/part-00003-39c2b748-5cab-46fb-8d6e-b1742fdd731a.c000.snappy.parquet")
    .load()
)
df2.display()

# %%
# Read the file but ignore partition directory structure
df2 = spark.read.format("parquet") \
    .option("mergeSchema", "false") \
    .parquet("/Volumes/workspace/default/practice/Partition/Country=France/part-00003-39c2b748-5cab-46fb-8d6e-b1742fdd731a.c000.snappy.parquet")

# Check schema
df2.printSchema()

# %%
df3 = spark.read.format("delta").option("path","/Volumes/workspace/default/practice/Partition/").load()
df3.display()

# %%
from pyspark.sql.functions import *

# %%
dfnew = df.withColumn("Year",year("OrderDate"))
display(dfnew)

# %%
dfnew.write.option("path","/Volumes/workspace/default/practice/Partition2/").partitionBy("Country","Year").save()

# %%
df5 = spark.read.format("delta").option("path","/Volumes/workspace/default/practice/Partition2/").load()
df5.display()

# %%
df5.createTempView("vworders")

# %%
# %sql
select * from vworders where Country='France'
