# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Employees.csv").option("header","true").option("inferSchema","true").load()
display(df)

# %%
df.write.saveAsTable("emptbl")

# %%
# %sql
alter table emptbl
drop column city

# %%
# %sql
alter table emptbl set tblproperties(
  'delta.columnMapping.mode' = 'name',
  'delta.minReaderVersion' = '2',
  'delta.minWriterVersion' = '5'
)

# %%
# %sql
alter table emptbl
drop column city

# %%
# %sql
select * from emptbl

# %%
# %sql
reorg table emptbl apply(purge)

# %%
# %sql
optimize emptbl

# %%
# %sql
vacuum emptbl retain 1 hours

# %%
# %sql
select * from emptbl

# %%
# %sql
drop table emptbl
