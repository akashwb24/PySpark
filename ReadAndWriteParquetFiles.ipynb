# %%
df = (spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load())
display(df)

# %%
df.repartition(1).write.format("parquet").mode("overwrite/Volumes/workspace/default/practice").option("path","/Volumes/workspace/default/practice/PAR2CSVProducts").save()

# %%
df2=spark.read.format("parquet").option("path","/Volumes/workspace/default/practice/PAR2CSVProducts/part-00000-tid-2825553239852457456-6e86a082-367a-42a0-8313-bcb6fa04e1c7-217-1.c000.snappy.parquet").load()
df2.display()

# %%
display(spark.read.text("/Volumes/workspace/default/practice/PAR2CSVProducts/part-00000-tid-2825553239852457456-6e86a082-367a-42a0-8313-bcb6fa04e1c7-217-1.c000.snappy.parquet"))
