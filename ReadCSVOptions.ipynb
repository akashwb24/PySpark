# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Employees-comment.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Employees-comment.csv").option("header",True).option("inferSchema",True).option("delimiter","|").load()
df.display()

# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Employees-comment.csv").option("header",True).option("inferSchema",True).option("delimiter","|").option("comment","#").load()
df.display()

# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/SalesMultiline.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/SalesMultiline.csv").option("header",True).option("inferSchema",True).option("delimiter","|").load()
df.display()

# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/SalesMultiline.csv").option("header",True).option("inferSchema",True).option("delimiter","|").option("multiline",True).load()
df.display()

# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/EmployeesSpace.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
from pyspark.sql.functions import *

# %%
df2 = df.withColumn("collen",length("name"))
df2.display()

# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/EmployeesSpace.csv").option("header",True).option("inferSchema",True).option("ignoreLeadingWhiteSpace",True).option("ignoreTrailingWhiteSpace",True).load()
df.display()

# %%
df2 = df.withColumn("collen",length("name"))
df2.display()
