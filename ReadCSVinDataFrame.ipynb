# %%
help(spark.read.csv)

# %%
df = spark.read.csv("/Volumes/workspace/default/practice/Products.csv")

# %%
df.collect()

# %%
display(df)

# %%
df.display()

# %%
df2 = spark.read.csv("/Volumes/workspace/default/practice/Products.csv", header=True)

# %%
df2.display()

# %%
df3 = spark.read.csv("/Volumes/workspace/default/practice/Products.csv", header=True, inferSchema=True)
df3.display()

# %%
df3.printSchema()

# %%
df4 = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()

# %%
display(df4)

# %%
df4 = spark.read.format("csv") \
.option("path","/Volumes/workspace/default/practice/Products.csv") \
.option("header",True) \
.option("inferSchema",True) \
.load()
display(df4)

# %%
df4 = (spark.read.format("csv")
.option("path","/Volumes/workspace/default/practice/Products.csv")
.option("header",True)
.option("inferSchema",True)
.load())
display(df4)
