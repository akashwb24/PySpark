# %%
df = spark.read.format("json").option("path","/Volumes/workspace/default/practice/Products.json").option("multiline",True).load()
display(df)

# %%
display(spark.read.text("/Volumes/workspace/default/practice/Products.json"))

# %%
df2 = spark.read.format("json").option("path","/Volumes/workspace/default/practice/ProductsNested.json").option("multiline",True).load()
display(df2)

# %%
display(spark.read.text("/Volumes/workspace/default/practice/ProductsNested.json")
)

# %%
df3 = df2.select("ProductKey","Detail.ProductName","Detail.Price","Detail.SalesAmount")
df3.display()
