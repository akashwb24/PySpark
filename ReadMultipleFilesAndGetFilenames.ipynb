# %%
df = (
    spark.read.format("csv")
    .option("header",True)
    .option("inferSchema",True)
    .option("path","/Volumes/workspace/default/practice/Countries")
    .load()
)
display(df)

# %%
from pyspark.sql.functions import input_file_name, split,regexp_replace

# %%
df2=df.withColumn("Filename",input_file_name()).select("Filenaame").distinct()
display(df2)

# %%
df3=df.withColumn("Countries",regex_replace(split(input_file_name(),"/"[4],".csv",""))
df3.display()
