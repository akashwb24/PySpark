# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/EmployeesNew.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
df2 = df.distinct()
df2.display()

# %%
display(df.select("city").distinct())

# %%
df3 = df.dropDuplicates()
df3.display()

# %%
df4 = df.dropDuplicates(["city"])
df4.display()

# %%
df5=df.dropDuplicates(["city","name"])
df5.display()
