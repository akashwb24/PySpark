# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
df2 = df.withColumnRenamed("ProductKey","ProductID")
df2.display()

# %%
df3 = df.withColumnRenamed("ProductKey","ProductID").withColumnRenamed("InvoiceNum","InvoiceID")
df3.display()

# %%
from pyspark.sql.functions import expr
df4 = df.selectExpr("*","InvoiceNum as InvoiceID").drop("InvoiceNum")
display(df4)

# %%
from pyspark.sql.functions import expr
df4 = df.selectExpr("*","InvoiceNum as InvoiceID")
display(df4)
