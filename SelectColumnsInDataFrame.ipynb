# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
df2 = df.select("OrderDate")
df2.display()

# %%
df3 = df.select("OrderDate", "EnglishProductName","SalesAmount")
df3.display()

# %%
df2 = df.selectExpr("OrderDate")
df2.display()

# %%
df3 = df.selectExpr("OrderDate", "EnglishProductName","SalesAmount")
df3.display()

# %%
df3 = df.selectExpr("OrderDate", "EnglishProductName","SalesAmount","round(SalesAmount * 0.05,2) as Vat")
df3.display()

# %%
from pyspark.sql.functions import expr

# %%
df4 = df.select("OrderDate", "EnglishProductName","SalesAmount",expr("round(SalesAmount * 0.05,2) as Vat"))
df4.display()

# %%
from pyspark.sql.functions import col

# %%
df5 = df.select(col("OrderDate"))
df5.display()

# %%
df6 = df.select(col("OrderDate"),col("EnglishProductName"),col("SalesAmount"))
df6.display()

# %%
from pyspark.sql.functions import expr, col

# %%
from pyspark.sql.functions import *
