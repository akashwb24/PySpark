# %%
df = spark.read.format("csv").option("path", "/Volumes/workspace/default/practice/Products.csv").option("header",True).option("inferSchema",True).load()
display(df)

# %%
df2 = df.sort("ProductKey")
df2.display()

# %%
df3 = df.sort("ProductKey")
df3.display()

# %%
df4 = df.sort("Country","ProductKey")
display(df4)

# %%
from pyspark.sql.functions import col

# %%
df4 = df.sort(col("Country").desc())
display(df4)

# %%
df5 = df.sort(col("Country").asc())
df5.display()

# %%
df6 = df.sort(col("Country").desc(), col("EnglishProductName").desc())
df6.display()
