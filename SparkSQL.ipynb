# %%
df = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/Products.csv")
    .option("header",True)
    .option("inferSchema",True)
    .load()
)
display(df)

# %%
df.createOrReplaceTempView("vwProducts")

# %%
# %sql
select * from vwProducts

# %%
_sqldf.count()

# %%
# %sql
select * from vwProducts where country='India'

# %%
_sqldf.count()

# %%
df2 = spark.sql("""select country, sum(salesamount) as TotalSales from vwProducts GROUP BY country""")
display(df2)

# %%
df3 = spark.sql("""select country, sum(salesamount) as TotalSales from vwProducts where year(orderdate)=2021 group by country""")
display(df3)

# %%
df.write.saveAsTable("tbl_products")

# %%
# %sql
select * from tbl_products

# %%
# %sql
delete from tbl_products where Invoicenum = 'INV100020'

# %%
spark.sql("delete from tbl_products where InvoiceNum = 'INV100021'")

# %%
# %sql
select count(*) from tbl_products

# %%
# %sql
update tbl_products set Country = 'USA' where Country = 'United States'

# %%
spark.sql("update tbl_products set country = 'United States' where Country = 'USA'")

# %%
dfcount = spark.sql("update tbl_products set country = 'USA' where country = 'United States'")
display(dfcount)

# %%
salesdf = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/Sales.csv")
    .option("header",True)
    .option("inferSchema",True)
    .load()
)
display(salesdf)

# %%
productsdf = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/ProductsNew.csv")
    .option("header",True)
    .option("inferSchema",True)
    .load()
)
display(productsdf)

# %%
customerdf = (
    spark.read.format("csv")
    .option("path","/Volumes/workspace/default/practice/Customers.csv")
    .option("header",True)
    .option("inferSchema",True)
    .load()
)
display(customerdf)

# %%
salesdf.createOrReplaceTempView("vwsales")
productsdf.createOrReplaceTempView("vwproducts")
customerdf.createOrReplaceTempView("vwcustomer")

# %%
joindf = spark.sql(""" select s.orderdate, s.salesamount, p.englishproductname, c.customername from vwsales as s join vwproducts p on s.productkey = p.productkey join vwcustomer c on s.customerkey = c.customerkey""")
display(joindf)

# %%
help(spark.sql)

# %%
dfnew = spark.sql("select * from {tablename} where country = 'India'",tablename=df)
display(dfnew)

# %%
dfnew = spark.sql("select {col1} from {tablename} where country = 'India'",col1=df.OrderDate, tablename=df)
display(dfnew)

# %%
dfnew = spark.sql("select {col1},{col2} from {tablename} where country = 'India'", col1=df.OrderDate, col2=df.SalesAmount, tablename=df)
display(dfnew)

# %%
dfnew = spark.sql("select {col1} ,sum(salesamount) as TotalSales from {tablename} group by {col1}",col1=df.Country, tablename=df)
display(dfnew)

# %%
param = df.Country
dfnew = spark.sql("select {col1}, sum(salesamount) as TotalSales from {tablename} group by {col1}", col1=param, tablename=df)
display(dfnew)

# %%
param = df.EnglishProductName
dfnew = spark.sql("select {col1}, sum(salesamount) as TotalSales from {tablename} group by {col1}", col1=param, tablename=df)
display(dfnew)
