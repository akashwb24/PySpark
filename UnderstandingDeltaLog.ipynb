# %%
dflog = (
    spark.read.format("json")
    .option("path","/Volumes/workspace/default/practice/Read&WriteDeltaFormat/_delta_log/00000000000000000000.json")
    .load()
)
display(dflog)

# %%
# %sql
select * from delta. `/Volumes/workspace/default/practice/Read&WriteDeltaFormat`

# %%
# %sql
update delta. `/Volumes/workspace/default/practice/Read&WriteDeltaFormat` set id = 20 where id = 5

# %%
# %sql
select * from delta. `/Volumes/workspace/default/practice/Read&WriteDeltaFormat/`

# %%
dflog2 = (
    spark.read.format("json")
    .option("path","/Volumes/workspace/default/practice/Read&WriteDeltaFormat/_delta_log/00000000000000000001.json")
    .load()
)
display(dflog2)

# %%
dflog3 = (
    spark.read.format("json")
    .option("path","/Volumes/workspace/default/practice/Read&WriteDeltaFormat/_delta_log/00000000000000000002.json")
    .load()
)
display(dflog3)

# %%
{"dataChange":false,"modificationTime":1774347213000,"path":"part-00000-383983fc-084a-4434-8240-419ac096db41.c000.snappy.parquet","size":684,"stats":"{\"numRecords\":10,\"minValues\":{\"id\":1},\"maxValues\":{\"id\":20},\"nullCount\":{\"id\":0},\"tightBounds\":true}","tags":{"INSERTION_TIME":"1774345665000000","MAX_INSERTION_TIME":"1774345665000007","MIN_INSERTION_TIME":"1774345665000000","NUM_AUTO_OPTIMIZES":"1","OPTIMIZE_TARGET_SIZE":"268435456"}}

# %%
# %sql
delete from delta. `/Volumes/workspace/default/practice/Read&WriteDeltaFormat` where id = 3

# %%
dflog4 = (
    spark.read.format("json")
    .option("path","/Volumes/workspace/default/practice/Read&WriteDeltaFormat/_delta_log/00000000000000000003.json")
    .load()
)
display(dflog4)

# %%
{"dataChange":true,"deletionVector":{"cardinality":1,"offset":1,"pathOrInlineDv":"Q:*lwF7NdOL-f9Y=I%hg","sizeInBytes":34,"storageType":"u"},"modificationTime":1774347213000,"path":"part-00000-383983fc-084a-4434-8240-419ac096db41.c000.snappy.parquet","size":684,"stats":"{\"numRecords\":10,\"minValues\":{\"id\":1},\"maxValues\":{\"id\":20},\"nullCount\":{\"id\":0},\"tightBounds\":false}","tags":{"INSERTION_TIME":"1774345665000000","MAX_INSERTION_TIME":"1774345665000007","MIN_INSERTION_TIME":"1774345665000000","NUM_AUTO_OPTIMIZES":"1","OPTIMIZE_TARGET_SIZE":"268435456"}}

# %%
# %sql
select * from delta. `/Volumes/workspace/default/practice/Read&WriteDeltaFormat`

# %%
# %sql
describe history delta. `/Volumes/workspace/default/practice/Read&WriteDeltaFormat`

# %%
from delta.tables import *
from pyspark.sql.functions import *

# %%
help(DeltaTable.forPath)

# %%
dtable = DeltaTable.forPath(spark,"/Volumes/workspace/default/practice/Read&WriteDeltaFormat")
type(dtable)

# %%
dtable.update(
    condition="id=6",
    set={"id":"60"}
)

# %%
dtable.delete(
    condition="id=7"
)

# %%
# %sql
select * from delta. `/Volumes/workspace/default/practice/Read&WriteDeltaFormat/`

# %%
# %sql
describe history delta. `/Volumes/workspace/default/practice/Read&WriteDeltaFormat/`
