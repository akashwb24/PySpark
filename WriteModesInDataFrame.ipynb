# %%
df = spark.read.format("csv").option("path","/Volumes/workspace/default/practice/Employees.csv").option("header",True).option("inferSchema",True).load()
df.display()

# %%
df2=spark.read.format("csv").option("path","/Volumes/workspace/default/practice/WriteEmployees.csv/").load()
df2.display()

# %%
df.write.format("csv").option("path","/Volumes/workspace/default/practice/WriteEmployees.csv").option("header",True).mode("append").save()

# %%
df.write.format("csv").option("path","/Volumes/workspace/default/practice/WriteEmployees.csv").option("header",True).mode("overwrite").save()

# %%
df.write.format("csv").option("path","/Volumes/workspace/default/practice/WriteEmployees.csv").option("header",True).mode("ignore").save()

# %%
df.write.format("csv").option("path","/Volumes/workspace/default/practice/WriteEmployees.csv").option("header",True).mode("error").save()

# %%
help(df.write)
