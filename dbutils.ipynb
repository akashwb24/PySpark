# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
display(dbutils.fs.ls("/Volumes/workspace/default/practice/"))
#array is outputby default, so get a dataframe like output display is used

# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/MyFolder")

# %%
dbutils.fs.rm("/Volumes/workspace/default/MyFolder")

# %%
dbutils.fs.rm("/Volumes/workspace/default/MyFolder", recurse=True)

# %%
dbutils.fs.cp("/Volumes/workspace/default/practice/", "/Volumes/workspace/default/MyFolder", recurse=True)

# %%
dbutils.fs.mv("/Volumes/workspace/default/MyFolder", "/Volumes/workspace/default/MyFolder", recurse=True)
