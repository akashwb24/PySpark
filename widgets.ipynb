# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("country","","Country")

# %%
dbutils.widgets.remove("country")

# %%
dbutils.widgets.get("country")

# %%
country = dbutils.widgets.get("country")
print(country)

# %%
dbutils.widgets.combobox("countries","",["india","russia","france"],"Select Country")

# %%
countries = dbutils.widgets.get("countries")
print(countries)

# %%
dbutils.widgets.dropdown("countriesdw","india",["india","russia","france"],"Select Country")

# %%
countriesdw = dbutils.widgets.get("countriesdw")
print(countriesdw)

# %%
dbutils.widgets.multiselect("countriesmulti","india",["india","russia","france"],"Select Country")

# %%
countriesmulti1 = dbutils.widgets.get("countriesmulti")
print(countriesmulti1)

# %%
dbutils.widgets.removeAll()
